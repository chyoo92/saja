# %%
import uproot
import numpy as np
from tqdm import tqdm
import torch
from torch_geometric.data import Data
import os

# %%
input_path = '/store/hep/users/yewzzang/saja/analysis_2/'
output_path = '/store/hep/users/yewzzang/saja/ttbar_pt_v2/'

# %%
file_list = os.listdir(input_path)

# %%
for files in tqdm(range(len(file_list))):
    
    f = uproot.open(input_path+file_list[files])
    data_list=[]
    for k in tqdm(range(len(np.array(f['tree']['jet_pt'])))):

        ## feature
        jet_pt = torch.from_numpy(np.array(f['tree']['jet_pt'])[k]).view(-1,1)
        jet_eta = torch.from_numpy(np.array(f['tree']['jet_eta'])[k]).view(-1,1)
        jet_phi = torch.from_numpy(np.array(f['tree']['jet_phi'])[k]).view(-1,1)
        jet_mass = torch.from_numpy(np.array(f['tree']['jet_mass'])[k]).view(-1,1)
        jet_btag = torch.from_numpy(np.array(f['tree']['jet_btag'])[k].astype(np.float32)).view(-1,1)

        
        ## jet_feature shape [N-Jet,5]
        jet_feature = torch.cat((jet_pt,
                                 jet_eta,
                                 jet_phi,
                                 jet_mass,
                                 jet_btag),dim=1)

        
        ## label [other, b_m, q0, q1, b_p, q2, q3]
        ## label [0, 1, 2, 2, 3, 4, 4]
        ## jet_label shape {N-Jet}
        jet_parton_match = np.array(f['tree']['jet_parton_match'])[k]+1

        ## find index
        index_3 = np.where(jet_parton_match==3)
        index_4 = np.where(jet_parton_match==4)
        index_5 = np.where(jet_parton_match==5)
        index_6 = np.where(jet_parton_match==6)

        ## change index
        jet_parton_match[index_3] = 2
        jet_parton_match[index_4] = 3
        jet_parton_match[index_5] = 4
        jet_parton_match[index_6] = 4
        
        print(jet_feature.shape)
        print(jet_label.shape)
        jet_label = torch.from_numpy(jet_parton_match)
        data = Data(x = jet_feature, y = jet_label)
        data_list.append(data)
    output_file = output_path + 'ttbar_'+file_list[files].split('.')[0].split('_')[1]+'.pt'

    torch.save(data_list,output_file)
# Out:
#   0%|                                                                          | 0/9999 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████| 160/160 [00:00<00:00, 1880.65it/s]
#   0%|                                                                          | 0/9999 [00:00<?, ?it/s]
# torch.Size([8, 5])
# torch.Size([8])
# torch.Size([6, 5])
# torch.Size([8])
# torch.Size([8, 5])
# torch.Size([6])
# torch.Size([8, 5])
# torch.Size([8])
# torch.Size([8, 5])
# torch.Size([8])
# torch.Size([6, 5])
# torch.Size([8])
# torch.Size([6, 5])
# torch.Size([6])
# torch.Size([8, 5])
# torch.Size([6])
# torch.Size([9, 5])
# torch.Size([8])
# torch.Size([8, 5])
# torch.Size([9])
# torch.Size([6, 5])
# torch.Size([8])
# torch.Size([7, 5])
# torch.Size([6])
# torch.Size([8, 5])
# torch.Size([7])
# torch.Size([8, 5])
# torch.Size([8])
# torch.Size([6, 5])
# torch.Size([8])
# torch.Size([7, 5])
# torch.Size([6])
# torch.Size([7, 5])
# torch.Size([7])
# torch.Size([7, 5])
# torch.Size([7])
# torch.Size

# torch.Size([7, 5])
# torch.Size([7])
# torch.Size([7, 5])
# torch.Size([7])
# torch.Size([8, 5])
# torch.Size([7])
# torch.Size([7, 5])
# torch.Size([8])
# torch.Size([10, 5])
# torch.Size([7])
# torch.Size([7, 5])
# torch.Size([10])
# torch.Size([6, 5])
# torch.Size([7])
# torch.Size([7, 5])
# torch.Size([6])
# torch.Size([8, 5])
# torch.Size([7])
# torch.Size([8, 5])
# torch.Size([8])
# torch.Size([8, 5])
# torch.Size([8])
# torch.Size([9, 5])
# torch.Size([8])
# torch.Size([6, 5])
# torch.Size([9])
# torch.Size([6, 5])
# torch.Size([6])
# torch.Size([7, 5])
# torch.Size([6])
# torch.Size([6, 5])
# torch.Size([7])
# torch.Size([6, 5])
# torch.Size([6])
# torch.Size([8, 5])
# torch.Size([6])
# torch.Size([6, 5])
# torch.Size([8])
# torch.Size([7, 5])
# torch.Size([6])
# torch.Size([7, 5])
# torch.Size([7])
# torch.Size([6, 5])
# torch.Size([7])
# torch.Size([9, 5])
# torch.Size([6])
# torch.Size([7, 5])
# torch.Size([9])
# torch.Size([7, 5])
# torch.Size([7])
# torch.Size([9, 5])
# torch.Size([7])
# torch.Size([8, 5])
# torch.Size([9])
# torch.Size([6, 5])
# torch.Size([8])
# torch.Size([7, 5])
# torch.Size([6])
# torch.Size([6, 5])
# torch.Size([7])
# torch.Size([6, 5])
# torch.Size([6])
# torch.Size([7, 5])
# torch.Size([6])
# torch.Size([6, 5])
# torch.Size([7])
# torch.Size([7, 5])
# torch.Size([6])
# torch.Size([7, 5])
# torch.Size([7])
# torch.Size([7, 5])
# torch.Size([7])
# torch.Size([6, 5])
# torch.Size([7])
# torch.Size([9, 5])
# torch.Size([6])
# torch.Size([8, 5])
# torch.Size([9])
# torch.Size([6, 5])
# torch.Size([8])
# torch.Size([6, 5])
# torch.Size([6])
# torch.Size([6, 5])
# torch.Size([6])
# torch.Size([7, 5])
# torch.Size([6])
# torch.Size([7, 5])
# torch.Size([7])
# torch.Size([8, 5])
# torch.Size([7])
# torch.Size([8, 5])
# torch.Size([8])
# torch.Size([7, 5])
# torch.Size([8])
# torch.Size([6, 5])
# torch.Size([7])
# torch.Size([6, 5])
# torch.Size([6])
# torch.Size([7, 5])
# torch.Size([6])
# torch.Size([8, 5])
# torch.Size([7])
# torch.Size([7, 5])
# torch.Size([8])
# torch.Size([6, 5])
# torch.Size([7])
# torch.Size([9, 5])
# torch.Size([6])
# torch.Size([8, 5])
# torch.Size([9])
# torch.Size([7, 5])
# torch.Size([8])
# torch.Size([9, 5])
# torch.Size([7])
# torch.Size([7, 5])
# torch.Size([9])
# torch.Size([7, 5])
# torch.Size([7])
# torch.Size([8, 5])
# torch.Size([7])
# torch.Size([8, 5])
# torch.Size([8])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 43
#      41     data_list.append(data)
#      42 output_file = output_path + 'ttbar_'+file_list[files].split('.')[0].split('_')[1]+'.pt'
# ---> 43 stop
#      44 torch.save(data_list,output_file)
#
# NameError: name 'stop' is not defined
